# %% [markdown]
# # **(ADD THE NOTEBOOK NAME HERE)**

# %% [markdown]
# ## Objectives
#
# * Write your notebook objective here, for example, "Fetch data from Kaggle and save as raw data", or "engineer features for modelling"
#
# ## Inputs
#
# * Write down which data or information you need to run the notebook
#
# ## Outputs
#
# * Write here which files, code or artefacts you generate by the end of the notebook
#
# ## Additional Comments
#
# * If you have any additional comments that don't fit in the previous bullets, please state them here.

# %% [markdown]
# ---

# %% [markdown]
# # Change working directory

# %% [markdown]
# * We are assuming you will store the notebooks in a subfolder, therefore when running the notebook in the editor, you will need to change the working directory

# %% [markdown]
# We need to change the working directory from its current folder to its parent folder
# * We access the current directory with os.getcwd()

# %%
import os
current_dir = os.getcwd()
current_dir
# Out:
# 'c:\\Users\\Legion\\my_test\\Deom_test\\jupyter_notebooks'

# %% [markdown]
# We want to make the parent of the current directory the new current directory
# * os.path.dirname() gets the parent directory
# * os.chir() defines the new current directory

# %%
os.chdir(os.path.dirname(current_dir))
print("You set a new current directory")
# Out:
# You set a new current directory

# %% [markdown]
# Confirm the new current directory

# %%
current_dir = os.getcwd()
current_dir
# Out:
# 'c:\\Users\\Legion\\my_test\\Deom_test'

# %% [markdown]
# # Section 1

# %% [markdown]
# Section 1 content

# %%
import pandas as pd #importing library

# %%
import numpy as np

# %%
import seaborn as sns

# %%
df = pd.read_csv('HRRAWDATA.csv')# reading the csv file
df.head()
# Out:
#    Age Attrition BusinessTravel  DailyRate              Department  \
# 0   51        No  Travel_Rarely        684  Research & Development
# 1   52        No  Travel_Rarely        699  Research & Development
# 2   42        No  Travel_Rarely        532  Research & Development
# 3   47        No  Travel_Rarely        359  Research & Development
# 4   46        No  Travel_Rarely       1319                   Sales
#
#    DistanceFromHome  Education    EducationField  EmployeeCount  \
# 0                 6          3     Life Sciences              1
# 1                 1          4     Life Sciences              1
# 2                 4          2  Technical Degree              1
# 3                 2          4           Medical              1
# 4                 3          3  Technical Degree              1
#
#    EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0             162  ...                         3            80
# ...

# %%
df.info() # displaying the information of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# ---

# %%
df.describe() # displaying the statistical information of the dataset
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.tail() # displaying the last 5 rows of the dataset
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   25        No      Travel_Rarely        309         Human Resources
# 1466   40        No      Travel_Rarely        543  Research & Development
# 1467   39        No         Non-Travel        105  Research & Development
# 1468   23       Yes  Travel_Frequently        638                   Sales
# 1469   35        No      Travel_Rarely       1146         Human Resources
#
#       DistanceFromHome  Education   EducationField  EmployeeCount  \
# 1465                 2          3  Human Resources              1
# 1466                 1          4    Life Sciences              1
# 1467                 9          3    Life Sciences              1
# 1468                 9          3        Marketing              1
# 1469                26          4    Life Sciences              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
df.value_counts() # displaying the count of unique values in the dataset
# Out:
# Age  Attrition  BusinessTravel  DailyRate  Department              DistanceFromHome  Education  EducationField    EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  JobRole                JobSatisfaction  MaritalStatus  MonthlyIncome  MonthlyRate  NumCompaniesWorked  Over18  OverTime  PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  StandardHours  StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# ...

# %% [markdown]
# # Section 2

# %% [markdown]
# Section 2 content

# %%
df.head() # displaying the first 5 rows of the dataset
# Out:
#    Age Attrition BusinessTravel  DailyRate              Department  \
# 0   51        No  Travel_Rarely        684  Research & Development
# 1   52        No  Travel_Rarely        699  Research & Development
# 2   42        No  Travel_Rarely        532  Research & Development
# 3   47        No  Travel_Rarely        359  Research & Development
# 4   46        No  Travel_Rarely       1319                   Sales
#
#    DistanceFromHome  Education    EducationField  EmployeeCount  \
# 0                 6          3     Life Sciences              1
# 1                 1          4     Life Sciences              1
# 2                 4          2  Technical Degree              1
# 3                 2          4           Medical              1
# 4                 3          3  Technical Degree              1
#
#    EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0             162  ...                         3            80
# ...

# %%
df.drop_duplicates(inplace=True) # removing duplicate rows from the dataset

# %%
df.describe() # after removing duplicates, displaying the statistical information of the dataset
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.fillna(method='ffill', inplace=True)# filling missing values with the previous value in the column
# Out:
# C:\Users\Legion\AppData\Local\Temp\ipykernel_40720\2672651380.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)# filling missing values with the previous value in the column

# %%
df.bfill(inplace=True) # filling missing values with the next value in the column
df.fillna
# Out:
# <bound method NDFrame.fillna of       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      51        No      Travel_Rarely        684  Research & Development
# 1      52        No      Travel_Rarely        699  Research & Development
# 2      42        No      Travel_Rarely        532  Research & Development
# 3      47        No      Travel_Rarely        359  Research & Development
# 4      46        No      Travel_Rarely       1319                   Sales
# ...   ...       ...                ...        ...                     ...
# 1465   25        No      Travel_Rarely        309         Human Resources
# 1466   40        No      Travel_Rarely        543  Research & Development
# 1467   39        No         Non-Travel        105  Research & Development
# 1468   23       Yes  Travel_Frequently        638                   Sales
# 1469   35        No      Travel_Rarely       1146         Human Resources
#
# ...

# %% [markdown]
# ---

# %%
df.bfill(inplace=True) # after filling missing values, displaying the information of the dataset

# %%
df.head() # displaying the first 5 rows of the dataset
# Out:
#    Age Attrition BusinessTravel  DailyRate              Department  \
# 0   51        No  Travel_Rarely        684  Research & Development
# 1   52        No  Travel_Rarely        699  Research & Development
# 2   42        No  Travel_Rarely        532  Research & Development
# 3   47        No  Travel_Rarely        359  Research & Development
# 4   46        No  Travel_Rarely       1319                   Sales
#
#    DistanceFromHome  Education    EducationField  EmployeeCount  \
# 0                 6          3     Life Sciences              1
# 1                 1          4     Life Sciences              1
# 2                 4          2  Technical Degree              1
# 3                 2          4           Medical              1
# 4                 3          3  Technical Degree              1
#
#    EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0             162  ...                         3            80
# ...

# %%
df.isnull()# displaying the null values in the dataset # There are no missing (null) values anywhere in the dataset
# Out:
#         Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0     False      False           False      False       False
# 1     False      False           False      False       False
# 2     False      False           False      False       False
# 3     False      False           False      False       False
# 4     False      False           False      False       False
# ...     ...        ...             ...        ...         ...
# 1465  False      False           False      False       False
# 1466  False      False           False      False       False
# 1467  False      False           False      False       False
# 1468  False      False           False      False       False
# 1469  False      False           False      False       False
#
#       DistanceFromHome  Education  EducationField  EmployeeCount  \
# 0                False      False           False          False
# 1                False      False           False          False
# ...

# %% [markdown]
# NOTE

# %%
df.describe()# after filling missing values, displaying the statistical information of the dataset
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.dropna() # removing rows with null values
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      51        No      Travel_Rarely        684  Research & Development
# 1      52        No      Travel_Rarely        699  Research & Development
# 2      42        No      Travel_Rarely        532  Research & Development
# 3      47        No      Travel_Rarely        359  Research & Development
# 4      46        No      Travel_Rarely       1319                   Sales
# ...   ...       ...                ...        ...                     ...
# 1465   25        No      Travel_Rarely        309         Human Resources
# 1466   40        No      Travel_Rarely        543  Research & Development
# 1467   39        No         Non-Travel        105  Research & Development
# 1468   23       Yes  Travel_Frequently        638                   Sales
# 1469   35        No      Travel_Rarely       1146         Human Resources
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
df.dropna(subset=['Age', 'Department']) # removing rows with null values in specific columns
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      51        No      Travel_Rarely        684  Research & Development
# 1      52        No      Travel_Rarely        699  Research & Development
# 2      42        No      Travel_Rarely        532  Research & Development
# 3      47        No      Travel_Rarely        359  Research & Development
# 4      46        No      Travel_Rarely       1319                   Sales
# ...   ...       ...                ...        ...                     ...
# 1465   25        No      Travel_Rarely        309         Human Resources
# 1466   40        No      Travel_Rarely        543  Research & Development
# 1467   39        No         Non-Travel        105  Research & Development
# 1468   23       Yes  Travel_Frequently        638                   Sales
# 1469   35        No      Travel_Rarely       1146         Human Resources
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
df.dropna(how='all') #drop all the values
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      51        No      Travel_Rarely        684  Research & Development
# 1      52        No      Travel_Rarely        699  Research & Development
# 2      42        No      Travel_Rarely        532  Research & Development
# 3      47        No      Travel_Rarely        359  Research & Development
# 4      46        No      Travel_Rarely       1319                   Sales
# ...   ...       ...                ...        ...                     ...
# 1465   25        No      Travel_Rarely        309         Human Resources
# 1466   40        No      Travel_Rarely        543  Research & Development
# 1467   39        No         Non-Travel        105  Research & Development
# 1468   23       Yes  Travel_Frequently        638                   Sales
# 1469   35        No      Travel_Rarely       1146         Human Resources
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
df.drop_duplicates() # removing duplicate rows from dataset
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      51        No      Travel_Rarely        684  Research & Development
# 1      52        No      Travel_Rarely        699  Research & Development
# 2      42        No      Travel_Rarely        532  Research & Development
# 3      47        No      Travel_Rarely        359  Research & Development
# 4      46        No      Travel_Rarely       1319                   Sales
# ...   ...       ...                ...        ...                     ...
# 1465   25        No      Travel_Rarely        309         Human Resources
# 1466   40        No      Travel_Rarely        543  Research & Development
# 1467   39        No         Non-Travel        105  Research & Development
# 1468   23       Yes  Travel_Frequently        638                   Sales
# 1469   35        No      Travel_Rarely       1146         Human Resources
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
df.replace({'old': 'new'}) # replacing old values with new values in the dataset
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      51        No      Travel_Rarely        684  Research & Development
# 1      52        No      Travel_Rarely        699  Research & Development
# 2      42        No      Travel_Rarely        532  Research & Development
# 3      47        No      Travel_Rarely        359  Research & Development
# 4      46        No      Travel_Rarely       1319                   Sales
# ...   ...       ...                ...        ...                     ...
# 1465   25        No      Travel_Rarely        309         Human Resources
# 1466   40        No      Travel_Rarely        543  Research & Development
# 1467   39        No         Non-Travel        105  Research & Development
# 1468   23       Yes  Travel_Frequently        638                   Sales
# 1469   35        No      Travel_Rarely       1146         Human Resources
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
df.info() # after replacing values, displaying the information of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.isnull().sum() # displaying the count of null values in each column
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
# Count duplicate rows in the DataFrame
duplicate_count = df.duplicated().sum()

# Check if there are any duplicates
if duplicate_count > 0:
    print(f"There are {duplicate_count} duplicate rows in the dataset.")
else:
    print("No duplicate rows found in the dataset.")
# Out:
# No duplicate rows found in the dataset.

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
df.corr
# Out:
# <bound method DataFrame.corr of       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      51        No      Travel_Rarely        684  Research & Development
# 1      52        No      Travel_Rarely        699  Research & Development
# 2      42        No      Travel_Rarely        532  Research & Development
# 3      47        No      Travel_Rarely        359  Research & Development
# 4      46        No      Travel_Rarely       1319                   Sales
# ...   ...       ...                ...        ...                     ...
# 1465   25        No      Travel_Rarely        309         Human Resources
# 1466   40        No      Travel_Rarely        543  Research & Development
# 1467   39        No         Non-Travel        105  Research & Development
# 1468   23       Yes  Travel_Frequently        638                   Sales
# 1469   35        No      Travel_Rarely       1146         Human Resources
#
# ...

# %%
np.unique
# Out:
# <function unique at 0x0000014B481CC1B0>

# %%
df.nunique()
# Out:
# Age                           43
# Attrition                      2
# BusinessTravel                 3
# DailyRate                    886
# Department                     3
# DistanceFromHome              29
# Education                      5
# EducationField                 6
# EmployeeCount                  1
# EmployeeNumber              1470
# EnvironmentSatisfaction        4
# Gender                         2
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobRole                        9
# JobSatisfaction                4
# MaritalStatus                  3
# MonthlyIncome               1349
# MonthlyRate                 1427
# NumCompaniesWorked            10
# Over18                         1
# OverTime                       2
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StandardHours                  1
# StockOptionLevel               4
# ...

# %%
return_counts=True  #number of times each value appears.

return_index=True

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.rename(columns={
    'OldColumnName1': 'NewName1',
    'OldColumnName2': 'NewName2'
}, inplace=True)

# %%
df.rename
# Out:
# <bound method DataFrame.rename of       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      51        No      Travel_Rarely        684  Research & Development
# 1      52        No      Travel_Rarely        699  Research & Development
# 2      42        No      Travel_Rarely        532  Research & Development
# 3      47        No      Travel_Rarely        359  Research & Development
# 4      46        No      Travel_Rarely       1319                   Sales
# ...   ...       ...                ...        ...                     ...
# 1465   25        No      Travel_Rarely        309         Human Resources
# 1466   40        No      Travel_Rarely        543  Research & Development
# 1467   39        No         Non-Travel        105  Research & Development
# 1468   23       Yes  Travel_Frequently        638                   Sales
# 1469   35        No      Travel_Rarely       1146         Human Resources
#
# ...

# %%
df.select_dtypes
# Out:
# <bound method DataFrame.select_dtypes of       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      51        No      Travel_Rarely        684  Research & Development
# 1      52        No      Travel_Rarely        699  Research & Development
# 2      42        No      Travel_Rarely        532  Research & Development
# 3      47        No      Travel_Rarely        359  Research & Development
# 4      46        No      Travel_Rarely       1319                   Sales
# ...   ...       ...                ...        ...                     ...
# 1465   25        No      Travel_Rarely        309         Human Resources
# 1466   40        No      Travel_Rarely        543  Research & Development
# 1467   39        No         Non-Travel        105  Research & Development
# 1468   23       Yes  Travel_Frequently        638                   Sales
# 1469   35        No      Travel_Rarely       1146         Human Resources
#
# ...

# %%
# Select only numeric columns
numeric_df = df.select_dtypes(include='number')

# Select only object (string) columns
string_df = df.select_dtypes(include='object')

# Select numeric but exclude float columns
int_df = df.select_dtypes(include='number', exclude='float')

# %%
df.astype
# Out:
# <bound method NDFrame.astype of       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      51        No      Travel_Rarely        684  Research & Development
# 1      52        No      Travel_Rarely        699  Research & Development
# 2      42        No      Travel_Rarely        532  Research & Development
# 3      47        No      Travel_Rarely        359  Research & Development
# 4      46        No      Travel_Rarely       1319                   Sales
# ...   ...       ...                ...        ...                     ...
# 1465   25        No      Travel_Rarely        309         Human Resources
# 1466   40        No      Travel_Rarely        543  Research & Development
# 1467   39        No         Non-Travel        105  Research & Development
# 1468   23       Yes  Travel_Frequently        638                   Sales
# 1469   35        No      Travel_Rarely       1146         Human Resources
#
# ...

# %%
df.resample
# Out:
# <bound method NDFrame.resample of       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      51        No      Travel_Rarely        684  Research & Development
# 1      52        No      Travel_Rarely        699  Research & Development
# 2      42        No      Travel_Rarely        532  Research & Development
# 3      47        No      Travel_Rarely        359  Research & Development
# 4      46        No      Travel_Rarely       1319                   Sales
# ...   ...       ...                ...        ...                     ...
# 1465   25        No      Travel_Rarely        309         Human Resources
# 1466   40        No      Travel_Rarely        543  Research & Development
# 1467   39        No         Non-Travel        105  Research & Development
# 1468   23       Yes  Travel_Frequently        638                   Sales
# 1469   35        No      Travel_Rarely       1146         Human Resources
#
# ...

# %%
df.rolling
# Out:
# <bound method NDFrame.rolling of       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      51        No      Travel_Rarely        684  Research & Development
# 1      52        No      Travel_Rarely        699  Research & Development
# 2      42        No      Travel_Rarely        532  Research & Development
# 3      47        No      Travel_Rarely        359  Research & Development
# 4      46        No      Travel_Rarely       1319                   Sales
# ...   ...       ...                ...        ...                     ...
# 1465   25        No      Travel_Rarely        309         Human Resources
# 1466   40        No      Travel_Rarely        543  Research & Development
# 1467   39        No         Non-Travel        105  Research & Development
# 1468   23       Yes  Travel_Frequently        638                   Sales
# 1469   35        No      Travel_Rarely       1146         Human Resources
#
# ...

# %%
df.shift
# Out:
# <bound method DataFrame.shift of       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      51        No      Travel_Rarely        684  Research & Development
# 1      52        No      Travel_Rarely        699  Research & Development
# 2      42        No      Travel_Rarely        532  Research & Development
# 3      47        No      Travel_Rarely        359  Research & Development
# 4      46        No      Travel_Rarely       1319                   Sales
# ...   ...       ...                ...        ...                     ...
# 1465   25        No      Travel_Rarely        309         Human Resources
# 1466   40        No      Travel_Rarely        543  Research & Development
# 1467   39        No         Non-Travel        105  Research & Development
# 1468   23       Yes  Travel_Frequently        638                   Sales
# 1469   35        No      Travel_Rarely       1146         Human Resources
#
# ...

# %%
df.diff
# Out:
# <bound method DataFrame.diff of       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      51        No      Travel_Rarely        684  Research & Development
# 1      52        No      Travel_Rarely        699  Research & Development
# 2      42        No      Travel_Rarely        532  Research & Development
# 3      47        No      Travel_Rarely        359  Research & Development
# 4      46        No      Travel_Rarely       1319                   Sales
# ...   ...       ...                ...        ...                     ...
# 1465   25        No      Travel_Rarely        309         Human Resources
# 1466   40        No      Travel_Rarely        543  Research & Development
# 1467   39        No         Non-Travel        105  Research & Development
# 1468   23       Yes  Travel_Frequently        638                   Sales
# 1469   35        No      Travel_Rarely       1146         Human Resources
#
# ...

# %%
df.pct_change
# Out:
# <bound method NDFrame.pct_change of       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      51        No      Travel_Rarely        684  Research & Development
# 1      52        No      Travel_Rarely        699  Research & Development
# 2      42        No      Travel_Rarely        532  Research & Development
# 3      47        No      Travel_Rarely        359  Research & Development
# 4      46        No      Travel_Rarely       1319                   Sales
# ...   ...       ...                ...        ...                     ...
# 1465   25        No      Travel_Rarely        309         Human Resources
# 1466   40        No      Travel_Rarely        543  Research & Development
# 1467   39        No         Non-Travel        105  Research & Development
# 1468   23       Yes  Travel_Frequently        638                   Sales
# 1469   35        No      Travel_Rarely       1146         Human Resources
#
# ...

# %%
sns.get_dataset_names() #get access to all the datasets available
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
sns.load_dataset('diamonds')
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
df.head(100)
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0    51        No      Travel_Rarely        684  Research & Development
# 1    52        No      Travel_Rarely        699  Research & Development
# 2    42        No      Travel_Rarely        532  Research & Development
# 3    47        No      Travel_Rarely        359  Research & Development
# 4    46        No      Travel_Rarely       1319                   Sales
# ..  ...       ...                ...        ...                     ...
# 95   45        No         Non-Travel       1050                   Sales
# 96   33        No      Travel_Rarely        117  Research & Development
# 97   36        No  Travel_Frequently        469  Research & Development
# 98   45       Yes      Travel_Rarely       1449                   Sales
# 99   51        No  Travel_Frequently        237                   Sales
#
#     DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
df= df.head(100)

# %%
df.head()
# Out:
#    Age Attrition BusinessTravel  DailyRate              Department  \
# 0   51        No  Travel_Rarely        684  Research & Development
# 1   52        No  Travel_Rarely        699  Research & Development
# 2   42        No  Travel_Rarely        532  Research & Development
# 3   47        No  Travel_Rarely        359  Research & Development
# 4   46        No  Travel_Rarely       1319                   Sales
#
#    DistanceFromHome  Education    EducationField  EmployeeCount  \
# 0                 6          3     Life Sciences              1
# 1                 1          4     Life Sciences              1
# 2                 4          2  Technical Degree              1
# 3                 2          4           Medical              1
# 4                 3          3  Technical Degree              1
#
#    EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0             162  ...                         3            80
# ...

# %%
variable= (lambda x: x + 10)(45) 
variable
# Out:
# 55

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df.sort_values #use this code to sort your data
# Out:
# <bound method DataFrame.sort_values of     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0    51        No      Travel_Rarely        684  Research & Development
# 1    52        No      Travel_Rarely        699  Research & Development
# 2    42        No      Travel_Rarely        532  Research & Development
# 3    47        No      Travel_Rarely        359  Research & Development
# 4    46        No      Travel_Rarely       1319                   Sales
# ..  ...       ...                ...        ...                     ...
# 95   45        No         Non-Travel       1050                   Sales
# 96   33        No      Travel_Rarely        117  Research & Development
# 97   36        No  Travel_Frequently        469  Research & Development
# 98   45       Yes      Travel_Rarely       1449                   Sales
# 99   51        No  Travel_Frequently        237                   Sales
#
# ...

# %%
df.pipe
# Out:
# <bound method NDFrame.pipe of     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0    51        No      Travel_Rarely        684  Research & Development
# 1    52        No      Travel_Rarely        699  Research & Development
# 2    42        No      Travel_Rarely        532  Research & Development
# 3    47        No      Travel_Rarely        359  Research & Development
# 4    46        No      Travel_Rarely       1319                   Sales
# ..  ...       ...                ...        ...                     ...
# 95   45        No         Non-Travel       1050                   Sales
# 96   33        No      Travel_Rarely        117  Research & Development
# 97   36        No  Travel_Frequently        469  Research & Development
# 98   45       Yes      Travel_Rarely       1449                   Sales
# 99   51        No  Travel_Frequently        237                   Sales
#
#     DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
np.random.seed(seed=101)

# %%
df_wide = pd.DataFrame(data= {'City': ['Cork','Dublin','Galway'],
                              'Day1':[25,21,14],
                              'Day2':[19,27,18],
                              'Day3':[23,16,10],
                              'Day4':[18,21,24]}
                  )
df_wide
# Out:
#      City  Day1  Day2  Day3  Day4
# 0    Cork    25    19    23    18
# 1  Dublin    21    27    16    21
# 2  Galway    14    18    10    24

# %%
import numpy as np
np.random.seed(seed=101)

df_long = pd.DataFrame(data= {'City':['Dublin','Dublin','Dublin','Dublin',
                                      'Cork','Cork','Cork','Cork','Galway',
                                      'Galway','Galway','Galway'],
                              'Day':[1,2,3,4]*3,
                              'AvgTemperature': np.random.randint(10,30,12)})

df_long
# Out:
#       City  Day  AvgTemperature
# 0   Dublin    1              21
# 1   Dublin    2              27
# 2   Dublin    3              16
# 3   Dublin    4              21
# 4     Cork    1              25
# 5     Cork    2              19
# 6     Cork    3              23
# 7     Cork    4              18
# 8   Galway    1              14
# 9   Galway    2              18
# 10  Galway    3              10
# 11  Galway    4              24

# %%
df_wide = pd.DataFrame(data= {'City': ['Cork','Dublin','Galway'],
                              'Day1':[25,21,14],
                              'Day2':[19,27,18],
                              'Day3':[23,16,10],
                              'Day4':[18,21,24]}
                  )
df_wide
# Out:
#      City  Day1  Day2  Day3  Day4
# 0    Cork    25    19    23    18
# 1  Dublin    21    27    16    21
# 2  Galway    14    18    10    24

# %%
pd.pivot_table
# Out:
# <function pandas.core.reshape.pivot.pivot_table(data: 'DataFrame', values=None, index=None, columns=None, aggfunc: 'AggFuncType' = 'mean', fill_value=None, margins: 'bool' = False, dropna: 'bool' = True, margins_name: 'Hashable' = 'All', observed: 'bool' = False, sort: 'bool' = True) -> 'DataFrame'>

# %%
df_wide
# Out:
#      City  Day1  Day2  Day3  Day4
# 0    Cork    25    19    23    18
# 1  Dublin    21    27    16    21
# 2  Galway    14    18    10    24

# %%
pd.melt
# Out:
# <function pandas.core.reshape.melt.melt(frame: 'DataFrame', id_vars=None, value_vars=None, var_name=None, value_name: 'Hashable' = 'value', col_level=None, ignore_index: 'bool' = True) -> 'DataFrame'>

# %%
pd.pivot_table
# Out:
# <function pandas.core.reshape.pivot.pivot_table(data: 'DataFrame', values=None, index=None, columns=None, aggfunc: 'AggFuncType' = 'mean', fill_value=None, margins: 'bool' = False, dropna: 'bool' = True, margins_name: 'Hashable' = 'All', observed: 'bool' = False, sort: 'bool' = True) -> 'DataFrame'>

# %%
df.head()
# Out:
#    Age Attrition BusinessTravel  DailyRate              Department  \
# 0   51        No  Travel_Rarely        684  Research & Development
# 1   52        No  Travel_Rarely        699  Research & Development
# 2   42        No  Travel_Rarely        532  Research & Development
# 3   47        No  Travel_Rarely        359  Research & Development
# 4   46        No  Travel_Rarely       1319                   Sales
#
#    DistanceFromHome  Education    EducationField  EmployeeCount  \
# 0                 6          3     Life Sciences              1
# 1                 1          4     Life Sciences              1
# 2                 4          2  Technical Degree              1
# 3                 2          4           Medical              1
# 4                 3          3  Technical Degree              1
#
#    EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0             162  ...                         3            80
# ...

# %%
data = {'Product':['Bread','Bread','Milk','Milk','Milk','Butter','Butter','Butter'],
        'Person':['Anna','Anna','Brian','John','John','Carl','Sarah','Anna'],
        'Sales':[200,120,340,124,243,350,500,240],
        'Quantity':[3,5,3,8,2,7,5,4],
        'Margin':[100,20,280,50,100,67,300,200]}

df = pd.DataFrame(data)
df
# Out:
#   Product Person  Sales  Quantity  Margin
# 0   Bread   Anna    200         3     100
# 1   Bread   Anna    120         5      20
# 2    Milk  Brian    340         3     280
# 3    Milk   John    124         8      50
# 4    Milk   John    243         2     100
# 5  Butter   Carl    350         7      67
# 6  Butter  Sarah    500         5     300
# 7  Butter   Anna    240         4     200

# %%
by_group = df.groupby(by=['Product'])
by_group

# %%
df.reset_index(drop=True)
# Out:
#   Product Person  Sales  Quantity  Margin
# 0   Bread   Anna    200         3     100
# 1   Bread   Anna    120         5      20
# 2    Milk  Brian    340         3     280
# 3    Milk   John    124         8      50
# 4    Milk   John    243         2     100
# 5  Butter   Carl    350         7      67
# 6  Butter  Sarah    500         5     300
# 7  Butter   Anna    240         4     200

# %%
pd.concat([df] ,axis=0)
# Out:
#   Product Person  Sales  Quantity  Margin
# 0   Bread   Anna    200         3     100
# 1   Bread   Anna    120         5      20
# 2    Milk  Brian    340         3     280
# 3    Milk   John    124         8      50
# 4    Milk   John    243         2     100
# 5  Butter   Carl    350         7      67
# 6  Butter  Sarah    500         5     300
# 7  Butter   Anna    240         4     200

# %%
df.iloc[0:5]
# Out:
#   Product Person  Sales  Quantity  Margin
# 0   Bread   Anna    200         3     100
# 1   Bread   Anna    120         5      20
# 2    Milk  Brian    340         3     280
# 3    Milk   John    124         8      50
# 4    Milk   John    243         2     100

# %%
import matplotlib.pyplot as plt

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('flights')
df = df.head(50)
print(df.shape)
df.head
# Out:
# (50, 3)
# <bound method NDFrame.head of     year month  passengers
# 0   1949   Jan         112
# 1   1949   Feb         118
# 2   1949   Mar         132
# 3   1949   Apr         129
# 4   1949   May         121
# 5   1949   Jun         135
# 6   1949   Jul         148
# 7   1949   Aug         148
# 8   1949   Sep         136
# 9   1949   Oct         119
# 10  1949   Nov         104
# 11  1949   Dec         118
# 12  1950   Jan         115
# 13  1950   Feb         126
# 14  1950   Mar         141
# 15  1950   Apr         135
# 16  1950   May         125
# 17  1950   Jun         149
# 18  1950   Jul         170
# 19  1950   Aug         170
# 20  1950   Sep         158
# 21  1950   Oct         133
# 22  1950   Nov         114
# 23  1950   Dec         140
# 24  1951   Jan         145
# 25  1951   Feb         150
# 26  1951   Mar         178
# 27  1951   Apr         163
# 28  1951   May         172
# 29  1951   Jun         178
# 30  1951   Jul         199
# 31  1951   Aug         199
# ...

# %%
pd.to_datetime
# Out:
# <function pandas.core.tools.datetimes.to_datetime(arg: 'DatetimeScalarOrArrayConvertible | DictConvertible', errors: 'DateTimeErrorChoices' = 'raise', dayfirst: 'bool' = False, yearfirst: 'bool' = False, utc: 'bool' = False, format: 'str | None' = None, exact: 'bool | lib.NoDefault' = <no_default>, unit: 'str | None' = None, infer_datetime_format: 'lib.NoDefault | bool' = <no_default>, origin: 'str' = 'unix', cache: 'bool' = True) -> 'DatetimeIndex | Series | DatetimeScalar | NaTType | None'>

# %%
df.set_index
# Out:
# <bound method DataFrame.set_index of     year month  passengers
# 0   1949   Jan         112
# 1   1949   Feb         118
# 2   1949   Mar         132
# 3   1949   Apr         129
# 4   1949   May         121
# 5   1949   Jun         135
# 6   1949   Jul         148
# 7   1949   Aug         148
# 8   1949   Sep         136
# 9   1949   Oct         119
# 10  1949   Nov         104
# 11  1949   Dec         118
# 12  1950   Jan         115
# 13  1950   Feb         126
# 14  1950   Mar         141
# 15  1950   Apr         135
# 16  1950   May         125
# 17  1950   Jun         149
# 18  1950   Jul         170
# 19  1950   Aug         170
# 20  1950   Sep         158
# 21  1950   Oct         133
# 22  1950   Nov         114
# 23  1950   Dec         140
# 24  1951   Jan         145
# 25  1951   Feb         150
# 26  1951   Mar         178
# 27  1951   Apr         163
# 28  1951   May         172
# 29  1951   Jun         178
# 30  1951   Jul         199
# 31  1951   Aug         199
# ...

# %%
df['year'] = df['year'].astype('str')
df['month'] = df['month'].astype('str')
df['Date'] = pd.to_datetime(df['month'] + '-' + df['year'] )
df.set_index('Date',inplace=True)
df.head()
# Out:
# C:\Users\Legion\AppData\Local\Temp\ipykernel_40720\1528758999.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date'] = pd.to_datetime(df['month'] + '-' + df['year'] )
#             year month  passengers
# Date
# 1949-01-01  1949   Jan         112
# 1949-02-01  1949   Feb         118
# 1949-03-01  1949   Mar         132
# 1949-04-01  1949   Apr         129
# 1949-05-01  1949   May         121

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create the DataFrame from your sample data
data = {
    'Date': ['1949-01-01', '1949-02-01', '1949-03-01', '1949-04-01', '1949-05-01'],
    'year': [1949, 1949, 1949, 1949, 1949],
    'month': ['Jan', 'Feb', 'Mar', 'Apr', 'May'],
    'passengers': [112, 118, 132, 129, 121]
}
df = pd.DataFrame(data)
df['Date'] = pd.to_datetime(df['Date'])

# Plot a bar chart
plt.figure(figsize=(8, 5))
plt.bar(df['month'], df['passengers'])
plt.title('Number of Passengers per Month (1949)')
plt.xlabel('Month')
plt.ylabel('Passengers')
plt.show()

# %%
df['Col1'] = 300 + 20 * np.random.randn(df.shape[0]) + np.random.randint(low=-10, high=20, size=df.shape[0])
df.head()
# Out:
#         Date  year month  passengers        Col1
# 0 1949-01-01  1949   Jan         112  274.636635
# 1 1949-02-01  1949   Feb         118  323.802441
# 2 1949-03-01  1949   Mar         132  310.576270
# 3 1949-04-01  1949   Apr         129  290.219989
# 4 1949-05-01  1949   May         121  304.773906

# %%
df.plot(kind='line',y=['passengers','Col1'],
        figsize=(10,6),
        title='Passengers and Col1 x Time', xlabel='Date', ylabel=' '
        )
plt.show()

# %%
df.head()
# Out:
#         Date  year month  passengers        Col1
# 0 1949-01-01  1949   Jan         112  274.636635
# 1 1949-02-01  1949   Feb         118  323.802441
# 2 1949-03-01  1949   Mar         132  310.576270
# 3 1949-04-01  1949   Apr         129  290.219989
# 4 1949-05-01  1949   May         121  304.773906

# %%
df.describe()
# Out:
#                       Date    year  passengers        Col1
# count                    5     5.0    5.000000    5.000000
# mean   1949-03-02 00:00:00  1949.0  122.400000  300.801848
# min    1949-01-01 00:00:00  1949.0  112.000000  274.636635
# 25%    1949-02-01 00:00:00  1949.0  118.000000  290.219989
# 50%    1949-03-01 00:00:00  1949.0  121.000000  304.773906
# 75%    1949-04-01 00:00:00  1949.0  129.000000  310.576270
# max    1949-05-01 00:00:00  1949.0  132.000000  323.802441
# std                    NaN     0.0    8.142481   18.953482

# %%
df.tail()
# Out:
#         Date  year month  passengers        Col1
# 0 1949-01-01  1949   Jan         112  274.636635
# 1 1949-02-01  1949   Feb         118  323.802441
# 2 1949-03-01  1949   Mar         132  310.576270
# 3 1949-04-01  1949   Apr         129  290.219989
# 4 1949-05-01  1949   May         121  304.773906

# %%
import seaborn as sns
df = sns.load_dataset('penguins')
df = df.sample(frac=0.33, random_state=1)
df.head()
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 306  Gentoo  Biscoe            43.4           14.4              218.0
# 341  Gentoo  Biscoe            50.4           15.7              222.0
# 291  Gentoo  Biscoe            46.4           15.6              221.0
# 102  Adelie  Biscoe            37.7           16.0              183.0
# 289  Gentoo  Biscoe            50.7           15.0              223.0
#
#      body_mass_g     sex
# 306       4600.0  Female
# 341       5750.0    Male
# 291       5000.0    Male
# 102       3075.0  Female
# 289       5550.0    Male

# %%
import pandas as pd
import plotly.express as px
import plotly.io as pio

# ✅ Ensure Plotly works in VS Code Jupyter
# 'iframe_connected' is the most reliable for VS Code
pio.renderers.default = "iframe_connected"

# Create the DataFrame
data = {
    "species": ["Gentoo", "Gentoo", "Gentoo", "Adelie", "Gentoo"],
    "island": ["Biscoe", "Biscoe", "Biscoe", "Biscoe", "Biscoe"],
    "bill_length_mm": [43.4, 50.4, 46.4, 37.7, 50.7],
    "bill_depth_mm": [14.4, 15.7, 15.6, 16.0, 15.0],
    "flipper_length_mm": [218.0, 222.0, 221.0, 183.0, 223.0],
    "body_mass_g": [4600.0, 5750.0, 5000.0, 3075.0, 5550.0],
    "sex": ["Female", "Male", "Male", "Female", "Male"]
}

df = pd.DataFrame(data)

# Create scatter plot
fig = px.scatter(
    df,
    x="bill_length_mm",
    y="flipper_length_mm",
    color="species",
    size="body_mass_g",
    hover_data=["sex", "island"],
    size_max=20,
    template="plotly_white",
    title="Penguin Bill Length vs Flipper Length (Sized by Body Mass)"
)

# Show plot
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_91.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Create the DataFrame
data = {
    "species": ["Gentoo", "Gentoo", "Gentoo", "Adelie", "Gentoo"],
    "island": ["Biscoe", "Biscoe", "Biscoe", "Biscoe", "Biscoe"],
    "bill_length_mm": [43.4, 50.4, 46.4, 37.7, 50.7],
    "bill_depth_mm": [14.4, 15.7, 15.6, 16.0, 15.0],
    "flipper_length_mm": [218.0, 222.0, 221.0, 183.0, 223.0],
    "body_mass_g": [4600.0, 5750.0, 5000.0, 3075.0, 5550.0],
    "sex": ["Female", "Male", "Male", "Female", "Male"]
}

df = pd.DataFrame(data)

# Set Seaborn style
sns.set(style="whitegrid")

# Create scatter plot
plt.figure(figsize=(8, 6))
scatter = sns.scatterplot(
    data=df,
    x="bill_length_mm",
    y="flipper_length_mm",
    hue="species",
    size="body_mass_g",
    sizes=(50, 300),  # min/max point size
    palette="deep",
    edgecolor="black"
)

# Add title
plt.title("Penguin Bill Length vs Flipper Length (Sized by Body Mass)", fontsize=14)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2)  # Move legend outside
plt.tight_layout()
plt.show()

# %%
df.info
# Out:
# <bound method DataFrame.info of   species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Gentoo  Biscoe            43.4           14.4              218.0
# 1  Gentoo  Biscoe            50.4           15.7              222.0
# 2  Gentoo  Biscoe            46.4           15.6              221.0
# 3  Adelie  Biscoe            37.7           16.0              183.0
# 4  Gentoo  Biscoe            50.7           15.0              223.0
#
#    body_mass_g     sex
# 0       4600.0  Female
# 1       5750.0    Male
# 2       5000.0    Male
# 3       3075.0  Female
# 4       5550.0    Male  >

# %%
df.plot(figsize=(10,6),colormap='hot')
plt.show()

# %%
import matplotlib.pyplot as plt
from collections import Counter

# Sample data from your table
species_data = ['Gentoo', 'Gentoo', 'Gentoo', 'Adelie', 'Gentoo']

# Count species occurrences
species_counts = Counter(species_data)

# Labels and values
labels = list(species_counts.keys())
sizes = list(species_counts.values())

# Colors and explode settings
colors = ['#66b3ff', '#ff9999']
explode = [0.1 if i == max(sizes) else 0 for i in sizes]  # Explode the largest slice

# Create pie chart
plt.figure(figsize=(6,6))
plt.pie(sizes, labels=labels, colors=colors, explode=explode, 
        autopct='%1.1f%%', shadow=True, startangle=140)

plt.title('Penguin Species Distribution')
plt.axis('equal')
plt.show()

# %% [markdown]
# * You may add as many sections as you want, as long as it supports your project workflow.
# * All notebook's cells should be run top-down (you can't create a dynamic wherein a given point you need to go back to a previous cell to execute some task, like go back to a previous cell and refresh a variable content)

# %% [markdown]
# ---

# %% [markdown]
# # Push files to Repo

# %% [markdown]
# * In cases where you don't need to push files to Repo, you may replace this section with "Conclusions and Next Steps" and state your conclusions and next steps.
